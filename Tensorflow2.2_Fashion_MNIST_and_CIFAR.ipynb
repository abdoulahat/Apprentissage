# %% [markdown]
# <a href="https://colab.research.google.com/github/abdoulahat/Apprentissage/blob/master/Tensorflow2_0_Fashion_MNIST_and_CIFAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CNN for Fashion MNIST**

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0

# %%
# additional imports
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.models import Model

# %%
# Load in the data
fashion_mnist = tf.keras.datasets.fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
print('x_train.shape:', x_train.shape)
# Out:
# x_train.shape: (60000, 28, 28)

# %%
# the data is only 2D
# convolution expects height x width x color
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print(x_train.shape)
# Out:
# (60000, 28, 28, 1)

# %%
# number of classes
K = len(set(y_train))
print('number of classes:', K)
# Out:
# number of classes: 10

# %%
# Build the model using function API
i = Input(shape=x_train[0].shape)
x = Conv2D(32, (3, 3), strides=2, activation='relu')(i)
x = Conv2D(64, (3, 3), strides=2, activation='relu')(x)
x = Conv2D(128, (3, 3), strides=2, activation='relu')(x)
x = Flatten()(x)
x = Dropout(0.2)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(K, activation='softmax')(x)

model = Model(i, x)

# %%
# Compile and fit
# Note: make sure you are using th GPU for this!
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
r = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.5207 - accuracy: 0.8076 - val_loss: 0.3917 - val_accuracy: 0.8533
# Epoch 2/15
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3568 - accuracy: 0.8662 - val_loss: 0.3439 - val_accuracy: 0.8750
# Epoch 3/15
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3073 - accuracy: 0.8836 - val_loss: 0.3246 - val_accuracy: 0.8800
# Epoch 4/15
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2747 - accuracy: 0.8973 - val_loss: 0.3067 - val_accuracy: 0.8881
# Epoch 5/15
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.2513 - accuracy: 0.9061 - val_loss: 0.3074 - val_accuracy: 0.8889
# Epoch 6/15
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2315 - accuracy: 0.9129 - val_loss: 0.2963 - val_accuracy: 0.8901
# Epoch 7/15
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2114 - accuracy: 0.9196 - val_loss: 0.2938 - val_accuracy: 0.8978
# Epoch 8/15
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1976 - accuracy: 0.9245 - val_loss: 0.3014 - val_accuracy: 0.8950
# Epoch 9/15
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1824 - accuracy: 0.9300 - val_loss: 0.3033 - val_accuracy: 0.8990
# Epoch 10/15
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.1698 - accuracy: 0.9351 - val_loss: 0.3063 - val_accuracy: 0.9008
# Epoch 11/15
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.1606 - accuracy: 0.9374 - val_loss: 0.3110 - val_accuracy: 0.9008
# Epoch 12/15
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1489 - accuracy: 0.9419 - val_loss: 0.3199 - val_accuracy: 0.9034
# Epoch 13/15
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1415 - accuracy: 0.9460 - val_loss: 0.3284 - val_accuracy: 0.9038
# Epoch 14/15
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1324 - accuracy: 0.9504 - val_loss: 0.3510 - val_accuracy: 0.9025
# Epoch 15/15
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1278 - accuracy: 0.9517 - val_loss: 0.3491 - val_accuracy: 0.9058

# %%
# PLot loss per iteration
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# PLot accuracy per iteration
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='confusion matrix',
                          cmap=plt.cm.Blues):
  
  """
  This function prints and plots the confusion matrix. 
  Normalizeation can be applied by setting 'normalize=True'.
  """

  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print('Normalize confusion matrix')
  else:
      print("Confusion matrix, without normalization")
  print(cm)

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '2.F' if normalize else 'd'
  thresh = cm.max() / 2
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment='center',
               color='white' if cm[i, j] > thresh else 'black')
  
  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# Confusion matrix, without normalization
# [[864   0  20  14   2   1  94   0   5   0]
#  [  1 974   2  14   2   0   5   0   2   0]
#  [ 17   1 856   7  45   0  70   0   4   0]
#  [ 22   5  16 913  22   0  20   0   2   0]
#  [  0   2  54  27 832   0  83   0   2   0]
#  [  0   0   0   0   0 962   0  28   2   8]
#  [109   0  52  19  61   0 750   0   9   0]
#  [  0   0   0   0   0   5   0 980   1  14]
#  [  1   1   3   5   6   2   6   4 972   0]
#  [  1   0   0   0   0   5   0  39   0 955]]

# %%
# Label mapping
labels = '''T-shirt/Top
Trouser
Pullover
Dress
Coat
Sandal
Shirt
Sneaker
Bag
Anke boot'''.split()

# %%
# Show some misclassified examples
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
plt.title('True label: %s Predicted: %s' % (labels[y_test[i]], labels[p_test[i]]));

# %% [markdown]
# # **CNN for CFAR-10**

# %%
# Load in the data
cifar10 = tf.keras.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
y_train, y_test = y_train.flatten(), y_test.flatten()
print('x_train.shape:', x_train.shape)
print('y_train.shape:', y_train.shape)
# Out:
# x_train.shape: (50000, 32, 32, 3)
# y_train.shape: (50000,)

# %%
# number of classes
K = len(set(y_train))
print('number of classes:', K)
# Out:
# number of classes: 10

# %%
# Build the model using function API
i = Input(shape=x_train[0].shape)
x = Conv2D(32, (3, 3), strides=2, activation='relu')(i)
x = Conv2D(64, (3, 3), strides=2, activation='relu')(x)
x = Conv2D(128, (3, 3), strides=2, activation='relu')(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(K, activation='softmax')(x)

model = Model(i, x)

# %%
# Compile and fit
# Note: make sure you are using th GPU for this!
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
r = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15)
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.5578 - accuracy: 0.4281 - val_loss: 1.2569 - val_accuracy: 0.5381
# Epoch 2/15
# 1563/1563 [==============================] - 53s 34ms/step - loss: 1.2652 - accuracy: 0.5470 - val_loss: 1.1269 - val_accuracy: 0.6014
# Epoch 3/15
# 1563/1563 [==============================] - 52s 34ms/step - loss: 1.1307 - accuracy: 0.5950 - val_loss: 1.0059 - val_accuracy: 0.6393
# Epoch 4/15
# 1563/1563 [==============================] - 47s 30ms/step - loss: 1.0357 - accuracy: 0.6295 - val_loss: 1.0076 - val_accuracy: 0.6518
# Epoch 5/15
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.9618 - accuracy: 0.6567 - val_loss: 0.8932 - val_accuracy: 0.6865
# Epoch 6/15
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.9014 - accuracy: 0.6794 - val_loss: 0.8866 - val_accuracy: 0.6989
# Epoch 7/15
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.8544 - accuracy: 0.6953 - val_loss: 0.8457 - val_accuracy: 0.7108
# Epoch 8/15
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.8125 - accuracy: 0.7113 - val_loss: 0.8359 - val_accuracy: 0.7111
# Epoch 9/15
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.7766 - accuracy: 0.7228 - val_loss: 0.8231 - val_accuracy: 0.7135
# Epoch 10/15
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.7480 - accuracy: 0.7366 - val_loss: 0.7911 - val_accuracy: 0.7271
# Epoch 11/15
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.7189 - accuracy: 0.7458 - val_loss: 0.8150 - val_accuracy: 0.7190
# Epoch 12/15
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.6941 - accuracy: 0.7537 - val_loss: 0.8099 - val_accuracy: 0.7196
# Epoch 13/15
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.6720 - accuracy: 0.7614 - val_loss: 0.8003 - val_accuracy: 0.7317
# Epoch 14/15
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.6437 - accuracy: 0.7710 - val_loss: 0.7830 - val_accuracy: 0.7326
# Epoch 15/15
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.6378 - accuracy: 0.7737 - val_loss: 0.7784 - val_accuracy: 0.7336

# %%
# PLot loss per iteration
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# PLot accuracy per iteration
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='confusion matrix',
                          cmap=plt.cm.Blues):
  
  """
  This function prints and plots the confusion matrix. 
  Normalizeation can be applied by setting 'normalize=True'.
  """

  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print('Normalize confusion matrix')
  else:
      print("Confusion matrix, without normalization")
  print(cm)

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '2.F' if normalize else 'd'
  thresh = cm.max() / 2
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment='center',
               color='white' if cm[i, j] > thresh else 'black')
  
  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# Confusion matrix, without normalization
# [[732  11  51  14  37  10  14  16  76  39]
#  [ 19 812   5   5   4   6  16   8  26  99]
#  [ 55   3 599  57 124  49  63  31  11   8]
#  [ 10   2  55 541  80 143 101  41  11  16]
#  [ 10   1  50  49 744  26  54  60   5   1]
#  [  3   2  48 180  67 580  60  50   3   7]
#  [  4   4  29  47  39  12 852   5   5   3]
#  [  8   0  22  41  46  43   7 821   1  11]
#  [ 44  22  19  10  16   6  14   7 836  26]
#  [ 34  47   6  22   9   9  10  22  22 819]]

# %%
# Label mapping
labels = '''airplane
automobile
bird
cat
deer
dog
frog
horse
ship
truck'''.split()

# %%
# Show some misclassified examples
# TODO: add label names
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(x_test[i], cmap='gray')
plt.title('True label: %s Predicted: %s' % (labels[y_test[i]], labels[p_test[i]]));

# %% [markdown]
# # **Improving CIFAR-10 Results**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, BatchNormalization, MaxPooling2D
from tensorflow.keras.models import Model

# %%
# Load in the data
cifar10 = tf.keras.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
y_train, y_test = y_train.flatten(), y_test.flatten()
print('x_train.shape:', x_train.shape)
print('y_train.shape:', y_train.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# x_train.shape: (50000, 32, 32, 3)
# y_train.shape: (50000,)

# %%
# number of classes
K = len(set(y_train))
print('number of classes:', K)
# Out:
# number of classes: 10

# %% [markdown]
# ### **Using BatchNormalization and MaxPooling2D**

# %%
# Build the model using function API
i = Input(shape=x_train[0].shape)
#x = Conv2D(32, (3, 3), strides=2, activation='relu')(i)
#x = Conv2D(64, (3, 3), strides=2, activation='relu')(x)
#x = Conv2D(128, (3, 3), strides=2, activation='relu')(x)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3),  activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
#x = Dropout(0.2)(x)
x = Conv2D(64, (3, 3),  activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3),  activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
#x = Dropout(0.2)(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
#x = Dropout(0.2)(x)

#x = GlobalMaxPoling2D()(x)
x = Flatten()(x)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(K, activation='softmax')(x)

model = Model(i, x)

# %%
# Compile and fit
# Note: make sure you are using the GPU for this!
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

r = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 26s 16ms/step - loss: 1.3240 - accuracy: 0.5419 - val_loss: 1.1434 - val_accuracy: 0.6068
# Epoch 2/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8546 - accuracy: 0.7052 - val_loss: 1.4641 - val_accuracy: 0.5192
# Epoch 3/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.6972 - accuracy: 0.7560 - val_loss: 0.8548 - val_accuracy: 0.7103
# Epoch 4/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.5935 - accuracy: 0.7970 - val_loss: 0.6678 - val_accuracy: 0.7775
# Epoch 5/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.5026 - accuracy: 0.8266 - val_loss: 0.6347 - val_accuracy: 0.7900
# Epoch 6/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.4234 - accuracy: 0.8537 - val_loss: 0.7012 - val_accuracy: 0.7784
# Epoch 7/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.3685 - accuracy: 0.8736 - val_loss: 0.5835 - val_accuracy: 0.8163
# Epoch 8/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.3005 - accuracy: 0.8954 - val_loss: 0.6760 - val_accuracy: 0.8070
# Epoch 9/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.2647 - accuracy: 0.9073 - val_loss: 0.6566 - val_accuracy: 0.8097
# Epoch 10/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.2228 - accuracy: 0.9236 - val_loss: 0.6497 - val_accuracy: 0.8262
# Epoch 11/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1999 - accuracy: 0.9315 - val_loss: 0.7275 - val_accuracy: 0.8160
# Epoch 12/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1861 - accuracy: 0.9368 - val_loss: 0.7338 - val_accuracy: 0.8141
# Epoch 13/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1612 - accuracy: 0.9438 - val_loss: 0.6598 - val_accuracy: 0.8224
# Epoch 14/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1469 - accuracy: 0.9501 - val_loss: 0.7733 - val_accuracy: 0.8014
# Epoch 15/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1350 - accuracy: 0.9539 - val_loss: 0.7249 - val_accuracy: 0.8251
# Epoch 16/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1328 - accuracy: 0.9551 - val_loss: 0.7670 - val_accuracy: 0.8249
# Epoch 17/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1200 - accuracy: 0.9588 - val_loss: 0.7121 - val_accuracy: 0.8320
# Epoch 18/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1080 - accuracy: 0.9639 - val_loss: 0.7097 - val_accuracy: 0.8306
# Epoch 19/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1107 - accuracy: 0.9633 - val_loss: 0.7154 - val_accuracy: 0.8285
# Epoch 20/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0975 - accuracy: 0.9687 - val_loss: 0.8052 - val_accuracy: 0.8288
# Epoch 21/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0950 - accuracy: 0.9692 - val_loss: 0.7873 - val_accuracy: 0.8297
# Epoch 22/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0885 - accuracy: 0.9705 - val_loss: 0.7674 - val_accuracy: 0.8327
# Epoch 23/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0882 - accuracy: 0.9704 - val_loss: 0.7315 - val_accuracy: 0.8327
# Epoch 24/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0802 - accuracy: 0.9741 - val_loss: 0.7523 - val_accuracy: 0.8275
# Epoch 25/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0763 - accuracy: 0.9748 - val_loss: 0.7918 - val_accuracy: 0.8365
# Epoch 26/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0768 - accuracy: 0.9743 - val_loss: 0.7611 - val_accuracy: 0.8319
# Epoch 27/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0740 - accuracy: 0.9756 - val_loss: 0.7854 - val_accuracy: 0.8298
# Epoch 28/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0731 - accuracy: 0.9762 - val_loss: 0.8059 - val_accuracy: 0.8443
# Epoch 29/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0640 - accuracy: 0.9791 - val_loss: 0.8325 - val_accuracy: 0.8277
# Epoch 30/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0605 - accuracy: 0.9798 - val_loss: 0.8671 - val_accuracy: 0.8373
# Epoch 31/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0668 - accuracy: 0.9790 - val_loss: 0.9271 - val_accuracy: 0.8397
# Epoch 32/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0635 - accuracy: 0.9794 - val_loss: 0.8302 - val_accuracy: 0.8381
# Epoch 33/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0576 - accuracy: 0.9816 - val_loss: 0.8646 - val_accuracy: 0.8209
# Epoch 34/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0575 - accuracy: 0.9813 - val_loss: 0.8049 - val_accuracy: 0.8331
# Epoch 35/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0587 - accuracy: 0.9806 - val_loss: 0.7929 - val_accuracy: 0.8339
# Epoch 36/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0540 - accuracy: 0.9830 - val_loss: 0.8022 - val_accuracy: 0.8367
# Epoch 37/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0526 - accuracy: 0.9827 - val_loss: 0.8044 - val_accuracy: 0.8350
# Epoch 38/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0505 - accuracy: 0.9831 - val_loss: 0.8841 - val_accuracy: 0.8406
# Epoch 39/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0502 - accuracy: 0.9838 - val_loss: 0.9440 - val_accuracy: 0.8307
# Epoch 40/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0515 - accuracy: 0.9827 - val_loss: 0.8789 - val_accuracy: 0.8299
# Epoch 41/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0489 - accuracy: 0.9840 - val_loss: 0.9164 - val_accuracy: 0.8323
# Epoch 42/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0492 - accuracy: 0.9839 - val_loss: 0.8672 - val_accuracy: 0.8318
# Epoch 43/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0442 - accuracy: 0.9858 - val_loss: 0.9591 - val_accuracy: 0.8373
# Epoch 44/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0446 - accuracy: 0.9853 - val_loss: 0.8458 - val_accuracy: 0.8415
# Epoch 45/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0470 - accuracy: 0.9855 - val_loss: 0.9257 - val_accuracy: 0.8348
# Epoch 46/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0493 - accuracy: 0.9846 - val_loss: 0.8995 - val_accuracy: 0.8406
# Epoch 47/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0410 - accuracy: 0.9863 - val_loss: 0.9386 - val_accuracy: 0.8388
# Epoch 48/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0429 - accuracy: 0.9863 - val_loss: 0.8823 - val_accuracy: 0.8393
# Epoch 49/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0409 - accuracy: 0.9872 - val_loss: 0.9321 - val_accuracy: 0.8326
# Epoch 50/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0485 - accuracy: 0.9846 - val_loss: 0.8423 - val_accuracy: 0.8420

# %%
# PLot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# PLot accuracy per iteration
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# ### **Fit with data augmentation**

# %%
# Note: if you run this AFTER calling the previous model.fit(), it will CONTINUE training where is left off
batch_size = 32
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
train_generator = data_generator.flow(x_train, y_train, batch_size)
steps_per_epoch = x_train.shape[0] // batch_size
r = model.fit_generator(train_generator, validation_data=(x_test, y_test), steps_per_epoch=steps_per_epoch, epochs=50)
# Out:
# WARNING:tensorflow:From <ipython-input-10-5d469bfe07b1>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.5574 - accuracy: 0.8235 - val_loss: 0.5829 - val_accuracy: 0.8197
# Epoch 2/50
# 1562/1562 [==============================] - 46s 30ms/step - loss: 0.4434 - accuracy: 0.8533 - val_loss: 0.4838 - val_accuracy: 0.8413
# Epoch 3/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.4097 - accuracy: 0.8640 - val_loss: 0.4517 - val_accuracy: 0.8508
# Epoch 4/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.3950 - accuracy: 0.8676 - val_loss: 0.4878 - val_accuracy: 0.8455
# Epoch 5/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.3799 - accuracy: 0.8728 - val_loss: 0.4247 - val_accuracy: 0.8580
# Epoch 6/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.3602 - accuracy: 0.8794 - val_loss: 0.4432 - val_accuracy: 0.8580
# Epoch 7/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.3459 - accuracy: 0.8840 - val_loss: 0.4311 - val_accuracy: 0.8625
# Epoch 8/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.3299 - accuracy: 0.8888 - val_loss: 0.4194 - val_accuracy: 0.8624
# Epoch 9/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.3265 - accuracy: 0.8894 - val_loss: 0.4747 - val_accuracy: 0.8524
# Epoch 10/50
# 1562/1562 [==============================] - 45s 28ms/step - loss: 0.3154 - accuracy: 0.8931 - val_loss: 0.4441 - val_accuracy: 0.8588
# Epoch 11/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.3053 - accuracy: 0.8978 - val_loss: 0.4350 - val_accuracy: 0.8631
# Epoch 12/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2955 - accuracy: 0.9000 - val_loss: 0.4204 - val_accuracy: 0.8670
# Epoch 13/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2840 - accuracy: 0.9040 - val_loss: 0.4544 - val_accuracy: 0.8626
# Epoch 14/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2811 - accuracy: 0.9042 - val_loss: 0.4155 - val_accuracy: 0.8637
# Epoch 15/50
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.2735 - accuracy: 0.9068 - val_loss: 0.4216 - val_accuracy: 0.8764
# Epoch 16/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2694 - accuracy: 0.9084 - val_loss: 0.4417 - val_accuracy: 0.8684
# Epoch 17/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2607 - accuracy: 0.9124 - val_loss: 0.4242 - val_accuracy: 0.8680
# Epoch 18/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2578 - accuracy: 0.9118 - val_loss: 0.4028 - val_accuracy: 0.8730
# Epoch 19/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2492 - accuracy: 0.9162 - val_loss: 0.4259 - val_accuracy: 0.8690
# Epoch 20/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2499 - accuracy: 0.9155 - val_loss: 0.4620 - val_accuracy: 0.8583
# Epoch 21/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2383 - accuracy: 0.9195 - val_loss: 0.4075 - val_accuracy: 0.8753
# Epoch 22/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2322 - accuracy: 0.9205 - val_loss: 0.4222 - val_accuracy: 0.8754
# Epoch 23/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2317 - accuracy: 0.9213 - val_loss: 0.4296 - val_accuracy: 0.8684
# Epoch 24/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2261 - accuracy: 0.9229 - val_loss: 0.3986 - val_accuracy: 0.8761
# Epoch 25/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2291 - accuracy: 0.9240 - val_loss: 0.4229 - val_accuracy: 0.8746
# Epoch 26/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.2221 - accuracy: 0.9246 - val_loss: 0.4246 - val_accuracy: 0.8687
# Epoch 27/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2179 - accuracy: 0.9262 - val_loss: 0.4272 - val_accuracy: 0.8715
# Epoch 28/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2180 - accuracy: 0.9256 - val_loss: 0.4123 - val_accuracy: 0.8776
# Epoch 29/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2088 - accuracy: 0.9294 - val_loss: 0.4179 - val_accuracy: 0.8732
# Epoch 30/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2078 - accuracy: 0.9302 - val_loss: 0.4246 - val_accuracy: 0.8699
# Epoch 31/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2106 - accuracy: 0.9293 - val_loss: 0.4142 - val_accuracy: 0.8764
# Epoch 32/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2046 - accuracy: 0.9293 - val_loss: 0.5197 - val_accuracy: 0.8510
# Epoch 33/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.2013 - accuracy: 0.9310 - val_loss: 0.4394 - val_accuracy: 0.8722
# Epoch 34/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1967 - accuracy: 0.9337 - val_loss: 0.4010 - val_accuracy: 0.8771
# Epoch 35/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1985 - accuracy: 0.9326 - val_loss: 0.4539 - val_accuracy: 0.8769
# Epoch 36/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1928 - accuracy: 0.9352 - val_loss: 0.3951 - val_accuracy: 0.8801
# Epoch 37/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1896 - accuracy: 0.9355 - val_loss: 0.4133 - val_accuracy: 0.8799
# Epoch 38/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1884 - accuracy: 0.9355 - val_loss: 0.4116 - val_accuracy: 0.8801
# Epoch 39/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1864 - accuracy: 0.9359 - val_loss: 0.4636 - val_accuracy: 0.8762
# Epoch 40/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1827 - accuracy: 0.9382 - val_loss: 0.4199 - val_accuracy: 0.8803
# Epoch 41/50
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.1822 - accuracy: 0.9384 - val_loss: 0.4120 - val_accuracy: 0.8767
# Epoch 42/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1785 - accuracy: 0.9397 - val_loss: 0.4706 - val_accuracy: 0.8746
# Epoch 43/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1762 - accuracy: 0.9406 - val_loss: 0.4445 - val_accuracy: 0.8742
# Epoch 44/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1768 - accuracy: 0.9410 - val_loss: 0.4305 - val_accuracy: 0.8824
# Epoch 45/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1782 - accuracy: 0.9389 - val_loss: 0.4444 - val_accuracy: 0.8761
# Epoch 46/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1690 - accuracy: 0.9423 - val_loss: 0.4119 - val_accuracy: 0.8818
# Epoch 47/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1720 - accuracy: 0.9417 - val_loss: 0.3917 - val_accuracy: 0.8799
# Epoch 48/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1704 - accuracy: 0.9422 - val_loss: 0.4307 - val_accuracy: 0.8850
# Epoch 49/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1705 - accuracy: 0.9434 - val_loss: 0.4838 - val_accuracy: 0.8728
# Epoch 50/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1654 - accuracy: 0.9445 - val_loss: 0.4079 - val_accuracy: 0.8834

# %%
# PLot loss per iteration
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# PLot accuracy per iteration
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='confusion matrix',
                          cmap=plt.cm.Blues):
  
  """
  This function prints and plots the confusion matrix. 
  Normalizeation can be applied by setting 'normalize=True'.
  """

  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print('Normalize confusion matrix')
  else:
      print("Confusion matrix, without normalization")
  print(cm)

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '2.F' if normalize else 'd'
  thresh = cm.max() / 2
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment='center',
               color='white' if cm[i, j] > thresh else 'black')
  
  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# Confusion matrix, without normalization
# [[916   6  25   8   6   0   3   3  23  10]
#  [  8 968   0   1   0   0   0   1   6  16]
#  [ 30   3 851  24  30  25  24   4   4   5]
#  [ 17   6  30 752  36  90  33  17   6  13]
#  [  8   0  32  25 881  14  20  17   3   0]
#  [  9   2  19 111  24 787  20  21   3   4]
#  [  8   4  21  27  13   0 916   4   4   3]
#  [ 10   2  12  16  23  17   2 911   2   5]
#  [ 32   8   2   3   1   2   1   1 934  16]
#  [ 10  56   1   2   2   0   2   0   9 918]]

# %%
# Label mapping
labels = '''airplane
automobile
bird
cat
deer
dog
frog
horse
ship
truck'''.split()

# %%
# Show some misclassified examples
# TODO: add label names
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(x_test[i], cmap='gray')
plt.title('True label: %s Predicted: %s' % (labels[y_test[i]], labels[p_test[i]]));

# %%
# Now that the model is so large, it's useful to summarize it
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 2,397,226
# Trainable params: 2,396,330
# Non-trainable params: 896
# _________________________________________________________________
